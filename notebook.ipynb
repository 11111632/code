# %%
import  numpy as np

# %%
arr = np.array(5)

# %%
print(arr)
# Out:
# 5

# %%
print(arr.ndim)
# Out:
# 0

# %%
arr = np.array([1,2,3])
print(arr)
print(arr.ndim)
# Out:
# [1 2 3]
# 1

# %% [markdown]
# #ni
